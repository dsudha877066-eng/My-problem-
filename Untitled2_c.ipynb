# %% [markdown]
# <a href="https://colab.research.google.com/github/dsudha877066-eng/My-problem-/blob/main/Untitled2_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include<iostream>
int main (){
    int arr{3}={1,2,3};
    int arr[i]=sum;
    printf("%d".arr[i]);
    return  0;
}
# Out:
#   File "/tmp/ipython-input-173109176.py", line 2
#     int main (){
#         ^
# SyntaxError: invalid syntax
